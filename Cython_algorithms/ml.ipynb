# %%
import gait_speed_walk_overall
video_path = "/Users/brennanlee/Desktop/opencv-healthcare/test/GSWT_normal_youlian.mp4"

person_height = 175  # Example height in meters
(
    test_name,
    normal_distance_walked,
    normal_elapsed_time,
    normal_average_speed,
    normal_average_stride_length,
    normal_keypoint_mean_magnitudes,
    normal_keypoint_std_devs,
    normal_keypoint_circular_mean,
    normal_keypoint_circular_std,
) = gait_speed_walk_overall.process_test(video_path, person_height, 400, False)

print(f"Test name: {test_name}")
print(f"Normal distance walked: {normal_distance_walked} meters")
print(f"Normal elapsed time: {normal_elapsed_time} seconds")
print(f"Normal average speed: {normal_average_speed} m/s")
print(f"Normal average stride length: {normal_average_stride_length} meters")
print(f"Normal keypoint mean magnitudes: {normal_keypoint_mean_magnitudes}")
print(f"Normal keypoint standard deviations: {normal_keypoint_std_devs}")
print(f"Normal keypoint circular mean: {normal_keypoint_circular_mean}")
print(f"Normal keypoint circular std: {normal_keypoint_circular_std}")
# Out:
# 2024-09-24 16:20:49,398 - INFO - Starting video processing
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 2024-09-24 16:20:50,181 - INFO - ===================== Processing frame 1 ==================================
# 2024-09-24 16:20:50,182 - INFO - --- Misc ---
# 2024-09-24 16:20:50,182 - INFO - Central ankle point: (0.07960475236177444, 0.9299815595149994)
# 2024-09-24 16:20:50,183 - INFO - Pixels to cm ratio: 7.24529003415789 is set
# 2024-09-24 16:20:50,184 - INFO - Central point: (0.10030108317732811, 0.6422167420387268)
# 2024-09-24 16:20:50,185 - INFO - --- End of Misc ---
# 2024-09-24 16:20:50,185 - INFO - Waiting for the person to start walking
# 2024-09-24 16:20:50,187 - INFO - --- Optical Flow ---
# 2024-09-24 16:20:50,187 - INFO - --- End of Optical Flow ---
# 2024-09-24 16:20:50,188 - INFO - --- Foot & Stride Information ---
# 2024-09-24 16:20:50,189 - INFO - Foot slope: 0.5214084843402751
# ...

# %%
# Fast walking
import gait_speed_walk_overall

video_path = "/Users/brennanlee/Desktop/opencv-healthcare/test/GSWT_fast_youlian.mp4"
person_height = 175  # Example height in meters
(
    test_name,
    fast_distance_walked,
    fast_elapsed_time,
    fast_average_speed,
    fast_average_stride_length,
    fast_keypoint_mean_magnitudes,
    fast_keypoint_std_devs,
    fast_keypoint_circular_mean,
    fast_keypoint_circular_std
) = gait_speed_walk_overall.process_test(video_path, person_height, 400, True)

print(f"Test name: {test_name}")
print(f"Fast distance walked: {fast_distance_walked} meters")
print(f"Fast elapsed time: {fast_elapsed_time} seconds")
print(f"Fast average speed: {fast_average_speed} m/s")
print(f"Fast average stride length: {fast_average_stride_length} meters")
print(f"Fast keypoint mean magnitudes: {fast_keypoint_mean_magnitudes}")
print(f"Fast keypoint standard deviations: {fast_keypoint_std_devs}")
print(f"Fast keypoint circular mean: {fast_keypoint_circular_mean}")
print(f"Fast keypoint circular std: {fast_keypoint_circular_std}")
# Out:
# 2024-09-24 15:02:05,076 - INFO - Starting video processing
# 2024-09-24 15:02:05,515 - INFO - ===================== Processing frame 1 ==================================
# 2024-09-24 15:02:05,958 - INFO - ===================== Processing frame 2 ==================================
# 2024-09-24 15:02:05,963 - INFO - --- Misc ---
# 2024-09-24 15:02:05,964 - INFO - Central ankle point: (0.059900907799601555, 0.9135852456092834)
# 2024-09-24 15:02:05,965 - INFO - Pixels to cm ratio: 6.935088239397321 is set
# 2024-09-24 15:02:05,966 - INFO - Central point: (0.08445025235414505, 0.6328490972518921)
# 2024-09-24 15:02:05,967 - INFO - --- End of Misc ---
# 2024-09-24 15:02:05,969 - INFO - Waiting for the person to start walking
# 2024-09-24 15:02:05,971 - INFO - --- Optical Flow ---
# 2024-09-24 15:02:05,972 - INFO - --- End of Optical Flow ---
# 2024-09-24 15:02:05,973 - INFO - --- Foot & Stride Information ---
# 2024-09-24 15:02:05,975 - INFO - Foot slope: 0.9514256284283966
# ...
