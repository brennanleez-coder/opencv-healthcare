# %%
import cv2
import mediapipe as mp
import numpy as np
import logging
cv2.setNumThreads(1)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)
mp_drawing = mp.solutions.drawing_utils

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    # define print method
    
    def __str__(self):
        return f'({self.x}, {self.y})'

def calculate_distance(point1, point2):
    return np.sqrt((point1.x - point2.x)**2 + (point1.y - point2.y)**2)
                # uncomment if 3d Point
                #    + (point1['z'] - point2['z'])**2)
                
def calculate_horizontal_distance(point1, point2, frame_width):
    return abs(point1.x - point2.x) * frame_width

def calculate_vertical_distance(point1, point2, frame_height):
    return abs(point1.y - point2.y) * frame_height

def calculate_central_point(landmark1, landmark2):
    return Point((landmark1.x + landmark2.x) / 2, (landmark1.y + landmark2.y) / 2)

def low_pass_filter(new_value, prev_value, alpha=0.8):
    return alpha * new_value + (1 - alpha) * prev_value

def calculate_foot_angle(ankle, toe):
    """
    Calculate the angle of the foot relative to the ground.

    Parameters:
        ankle (Point): The position of the ankle (with x, y coordinates).
        toe (Point): The position of the toe (with x, y coordinates).

    Returns:
        float: The angle of the foot in degrees.
    """
    delta_x = abs(ankle.x - toe.x)
    delta_y = abs(ankle.y - toe.y)

    # Calculate the angle in radians
    angle_radians = np.arctan2(delta_y, delta_x)

    # Convert the angle to degrees
    angle_degrees = abs(angle_radians * 180.0 / np.pi)
    
    if angle_degrees > 180.0:
        angle_degrees = 360.0 - angle_degrees

    return angle_degrees

def is_foot_parallel_to_ground(side, ankle, toe, angle_threshold=8):
    """
    Check if the foot is parallel to the ground based on the angle.

    Parameters:
        ankle (Point): The position of the ankle (with x, y coordinates).
        toe (Point): The position of the toe (with x, y coordinates).
        angle_threshold (float): The threshold within which the foot is considered parallel to the ground.

    Returns:
        bool: True if the foot is parallel to the ground, False otherwise.
    """
    foot_angle = calculate_foot_angle(ankle, toe)
    logging.info(f'{side} foot angle: {foot_angle}')
    # Check if the foot angle is close to 0 degrees (parallel to the ground)
    return abs(foot_angle) <= angle_threshold
def calculate_foot_slope(ankle, toe):
    return (toe.y - ankle.y) / (toe.x - ankle.x)
    
def is_foot_on_ground(side, prev_toe, curr_toe, ground_line_y, flow_magnitude, flow_threshold=0.01, y_threshold=0.01):
    # Determine if the toe is approaching or leaving the ground based on y-coordinate change
    toe_status_message = 'Toe approaching ground' if curr_toe.y < prev_toe.y else 'Toe leaving ground'
    
    # Apply a low-pass filter for smooth movement (already in place)
    low_pass_curr_toe_y = low_pass_filter(curr_toe.y, prev_toe.y)
    
    # Optical flow status: low flow magnitude suggests the foot is stationary (likely touching the ground)
    foot_stationary = flow_magnitude < flow_threshold
    flow_status_message = 'Foot stationary' if foot_stationary else 'Foot moving'

    
    # Log the current status
    logging.info(f'{side} curr_toe: ({curr_toe.x}, {curr_toe.y}), {toe_status_message}')
    logging.info(f'{side} point_y: {curr_toe.y}, ground_line_y: {ground_line_y}, {side} leg on ground: {low_pass_curr_toe_y < ground_line_y}')
    logging.info(f'{side} flow magnitude: {flow_magnitude}, {flow_status_message}')
    
    # Tolerance-based check for ground contact
    y_within_range = abs(low_pass_curr_toe_y - ground_line_y) < y_threshold

    # Foot on ground if it's within y-threshold and stationary (low flow)
    foot_on_ground = y_within_range and foot_stationary

    return foot_on_ground


# def get_actual_height_in_px()

# print(calculate_central_point(Point(1, 1), Point(2, 2)))
# print(calculate_distance(Point(1, 1), Point(2, 2)))

# %%
def gait_speed_walk_overall(
    video_path,
    person_height_in_cm,
    distance_required_in_cm,
    movement_threshold=0.02,
    debug=True,
):
    logging.info("Starting video processing")

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0:
        logging.error("Cannot determine the frame rate (FPS) of the video.")
        return 0, 0, 0  # Default values for stride length, elapsed time, and speed

    start_frame_id = None
    end_frame_id = None
    start_position = None
    distance_walked = 0
    timer_started = False
    initial_position = None
    strides = []

    previous_right_toe_position = None
    previous_left_toe_position = None
    right_foot_on_ground = False
    left_foot_on_ground = False

    central_point = None

    pixels_to_cm_ratio = None
    start_line = None
    ground_line = None

    ground_threshold = 0.08
    start_line_offset = 0.01

    previous_gray = None
    previous_keypoints = None
    pixels_to_cm_ratio = None  # Ratio to convert pixels to cm

    foot_contact_start = False  # Flag to track first contact
    foot_off_ground = False  # Flag to track if foot is lifted off ground
    reset_needed = False  # Flag to reset after stride is recorded
    initial_foot_slope = None  # Initial slope of the foot
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            logging.warning("End of video or cannot read the video file")
            break

        current_frame_id = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(frame_rgb)

        current_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        logging.info(
            f"===================== Processing frame {current_frame_id} =================================="
        )
        if results.pose_landmarks:
            # Draw pose landmarks
            if debug:
                mp_drawing.draw_landmarks(
                    frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS
                )

            landmarks = results.pose_landmarks.landmark
            # Convert NormalizedLandmark to Point
            left_hip = Point(
                landmarks[mp_pose.PoseLandmark.LEFT_HIP].x,
                landmarks[mp_pose.PoseLandmark.LEFT_HIP].y,
            )
            right_hip = Point(
                landmarks[mp_pose.PoseLandmark.RIGHT_HIP].x,
                landmarks[mp_pose.PoseLandmark.RIGHT_HIP].y,
            )
            nose = Point(
                landmarks[mp_pose.PoseLandmark.NOSE].x,
                landmarks[mp_pose.PoseLandmark.NOSE].y,
            )
            left_ankle = Point(
                landmarks[mp_pose.PoseLandmark.LEFT_ANKLE].x,
                landmarks[mp_pose.PoseLandmark.LEFT_ANKLE].y,
            )
            right_ankle = Point(
                landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE].x,
                landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE].y,
            )
            left_toe = Point(
                landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].x,
                landmarks[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].y,
            )
            right_toe = Point(
                landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].x,
                landmarks[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].y,
            )
            keypoints = {
                "LEFT_HIP": left_hip,
                "RIGHT_HIP": right_hip,
                "NOSE": nose,
                "LEFT_ANKLE": left_ankle,
                "RIGHT_ANKLE": right_ankle,
                "LEFT_TOE": left_toe,
                "RIGHT_TOE": right_toe,
            }
            keypoint_array = np.array(
                [
                    [kp.x * frame.shape[1], kp.y * frame.shape[0]]
                    for kp in keypoints.values()
                ],
                dtype=np.float32,
            ).reshape(-1, 1, 2)

            if previous_gray is not None and previous_keypoints is not None:
                p1, st, err = cv2.calcOpticalFlowPyrLK(
                    previous_gray, current_gray, previous_keypoints, None
                )
                for i, (new, old) in enumerate(zip(p1, previous_keypoints)):
                    new_x, new_y = new.ravel()
                    old_x, old_y = old.ravel()

                    motion_magnitude = np.sqrt(
                        (new_x - old_x) ** 2 + (new_y - old_y) ** 2
                    )
                    motion_angle = np.arctan2(new_y - old_y, new_x - old_x)

                    key = list(keypoints.keys())[i]
                    # logging.info(
                    #     f"{key} - Magnitude: {motion_magnitude}, Angle: {motion_angle} radians"
                    # )
                    if key == "LEFT_ANKLE":
                        left_ankle_motion_magnitude = motion_magnitude
                    elif key == "RIGHT_ANKLE":
                        right_ankle_motion_magnitude = motion_magnitude
                    elif key == "LEFT_TOE":
                        left_toe_motion_magnitude = motion_magnitude
                    elif key == "RIGHT_TOE":
                        right_toe_motion_magnitude = motion_magnitude
                    # Optionally, visualize the motion (debugging)
                    if debug:
                        cv2.arrowedLine(
                            frame,
                            (int(old_x), int(old_y)),
                            (int(new_x), int(new_y)),
                            (0, 255, 0),
                            2,
                            tipLength=0.5,
                        )
                previous_keypoints = p1
            else:
                previous_keypoints = keypoint_array
            previous_gray = current_gray

            central_ankle = calculate_central_point(left_ankle, right_ankle)
            # logging.info(f"Central ankle point: {central_ankle}")

            if ground_line is None:
                # Set the ground line slightly below the ankle
                ground_line = central_ankle.y + ground_threshold
                logging.info(f"Ground line set at Y: {ground_line}")
            else:
                if debug:
                    cv2.line(
                        frame,
                        (0, int(ground_line * frame.shape[0])),
                        (frame.shape[1], int(ground_line * frame.shape[0])),
                        (0, 255, 0),  # Green color for the ground line
                        2,
                    )
            estimated_height_in_px = calculate_vertical_distance(
                nose, central_ankle, frame.shape[0]
            )  # Possibly add a offset to the height

            if pixels_to_cm_ratio is None:
                pixels_to_cm_ratio = estimated_height_in_px / person_height_in_cm
                logging.info(f"Pixels to cm ratio: {pixels_to_cm_ratio} is set")
            if initial_foot_slope is None:
                initial_foot_slope = calculate_foot_slope(keypoints["RIGHT_ANKLE"], keypoints["RIGHT_TOE"])
                right_slope = calculate_foot_slope(keypoints["RIGHT_ANKLE"], keypoints["RIGHT_TOE"])
                logging.info(f"Initial foot slope: {initial_foot_slope}")
            else:
                right_slope = calculate_foot_slope(keypoints["RIGHT_ANKLE"], keypoints["RIGHT_TOE"])
                logging.info(f"Right foot slope: {right_slope}")
            
            if abs(right_slope) < initial_foot_slope:
                logging.info(f"Right foot is parallel to the ground")
                if not foot_contact_start and not reset_needed:
                    # First ground contact
                    foot_contact_start = True
                    foot_off_ground = False
                    initial_contact_position = right_toe
                    logging.info("First ground contact detected")

                elif foot_off_ground and reset_needed:
                    # Second ground contact, calculate stride
                    final_contact_position = right_toe
                    stride_length = (
                        calculate_horizontal_distance(
                            final_contact_position, initial_contact_position, frame.shape[1]
                        )
                        / pixels_to_cm_ratio
                    )
                    strides.append(stride_length)
                    logging.info(f"Stride length recorded: {stride_length} cm")

                    # Reset flags for the next stride detection
                    reset_needed = False
                    foot_contact_start = False
                    foot_off_ground = False
                    initial_contact_position = right_toe
            else:
                # Foot off ground
                if foot_contact_start and not reset_needed:
                    foot_off_ground = True
                    logging.info("Foot is off the ground")

                    # Allow reset to detect the next stride
                    reset_needed = True

            logging.info(f"Right foot slope: {right_slope}")
            cv2.putText(
                frame,
                f"Right foot slope: {right_slope}",
                (10, 80),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 0),
                2,
                cv2.LINE_AA,
            )
            if abs(right_slope) < 0.9:
                logging.info(f"Right foot is parallel to the ground")

            cv2.putText(
                frame,
                f"Foot touching ground: {'YES' if foot_contact_start and abs(right_slope) < 0.9 else 'NO'}",
                (10, 110),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 0),  # Yellow text for stride count
                2,
                cv2.LINE_AA,
            )
        if distance_walked >= distance_required_in_cm:
            logging.info(
                f"Distance walked: {distance_walked} cm, required distance reached"
            )
            break
        if debug:
            # Display the frame
            cv2.imshow("Frame", frame)
            if cv2.waitKey(5) & 0xFF == 27:
                logging.info("Process interrupted by user")
                break

    cap.release()
    cv2.destroyAllWindows()

    if strides:
        average_stride_length = np.mean(strides) * 2
    else:
        average_stride_length = 0

    if timer_started and start_frame_id is not None:
        elapsed_time = (current_frame_id - start_frame_id) / fps
        average_speed = distance_walked / elapsed_time if elapsed_time > 0 else 0
    else:
        elapsed_time = 0
        average_speed = 0

    return strides, elapsed_time, average_speed, distance_walked, average_stride_length


video_path = "/Users/brennanlee/Desktop/opencv-healthcare/test/GSWT_frail_youlian.mp4"
person_height = 175  # Example height in meters
strides, elapsed_time, average_speed, distance_walked, average_stride_length = (
    gait_speed_walk_overall(video_path, person_height, 400)
)
print(f"Average Stride Length: {average_stride_length}")
print(f"Time to walk {distance_walked} cm: {elapsed_time} seconds")
print(f"Average Speed: {average_speed} cm/second")
# Out:
# 2024-09-08 00:47:03,237 - INFO - Starting video processing
# 2024-09-08 00:47:03,661 - INFO - ===================== Processing frame 1 ==================================
# 2024-09-08 00:47:03,664 - INFO - Ground line set at Y: 1.008302675485611
# 2024-09-08 00:47:03,664 - INFO - Pixels to cm ratio: 6.925768865857806 is set
# 2024-09-08 00:47:03,665 - INFO - Initial foot slope: 0.4529777898454396
# 2024-09-08 00:47:03,666 - INFO - Right foot slope: 0.4529777898454396
# 2024-09-08 00:47:03,667 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:03,872 - INFO - ===================== Processing frame 2 ==================================
# 2024-09-08 00:47:03,913 - INFO - Right foot slope: 0.7272741440114465
# 2024-09-08 00:47:03,913 - INFO - Right foot slope: 0.7272741440114465
# 2024-09-08 00:47:03,915 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:04,068 - INFO - ===================== Processing frame 3 ==================================
# 2024-09-08 00:47:04,088 - INFO - Right foot slope: 0.7700060501903399
# 2024-09-08 00:47:04,088 - INFO - Right foot slope: 0.7700060501903399
# 2024-09-08 00:47:04,090 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:04,237 - INFO - ===================== Processing frame 4 ==================================
# 2024-09-08 00:47:04,263 - INFO - Right foot slope: 0.8852611732483741
# 2024-09-08 00:47:04,264 - INFO - Right foot slope: 0.8852611732483741
# 2024-09-08 00:47:04,265 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:04,423 - INFO - ===================== Processing frame 5 ==================================
# 2024-09-08 00:47:04,445 - INFO - Right foot slope: 0.8786597656744728
# 2024-09-08 00:47:04,446 - INFO - Right foot slope: 0.8786597656744728
# 2024-09-08 00:47:04,447 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:04,591 - INFO - ===================== Processing frame 6 ==================================
# 2024-09-08 00:47:04,613 - INFO - Right foot slope: 0.9365224024136853
# 2024-09-08 00:47:04,614 - INFO - Right foot slope: 0.9365224024136853
# 2024-09-08 00:47:04,757 - INFO - ===================== Processing frame 7 ==================================
# 2024-09-08 00:47:04,777 - INFO - Right foot slope: 0.9973718130150975
# 2024-09-08 00:47:04,777 - INFO - Right foot slope: 0.9973718130150975
# 2024-09-08 00:47:04,918 - INFO - ===================== Processing frame 8 ==================================
# 2024-09-08 00:47:04,940 - INFO - Right foot slope: 1.1399855851723841
# 2024-09-08 00:47:04,941 - INFO - Right foot slope: 1.1399855851723841
# 2024-09-08 00:47:05,084 - INFO - ===================== Processing frame 9 ==================================
# 2024-09-08 00:47:05,105 - INFO - Right foot slope: 1.1652496117755773
# 2024-09-08 00:47:05,106 - INFO - Right foot slope: 1.1652496117755773
# 2024-09-08 00:47:05,249 - INFO - ===================== Processing frame 10 ==================================
# 2024-09-08 00:47:05,271 - INFO - Right foot slope: 1.2438272008234084
# 2024-09-08 00:47:05,271 - INFO - Right foot slope: 1.2438272008234084
# 2024-09-08 00:47:05,411 - INFO - ===================== Processing frame 11 ==================================
# 2024-09-08 00:47:05,430 - INFO - Right foot slope: 1.2594485205765351
# 2024-09-08 00:47:05,431 - INFO - Right foot slope: 1.2594485205765351
# 2024-09-08 00:47:05,570 - INFO - ===================== Processing frame 12 ==================================
# 2024-09-08 00:47:05,592 - INFO - Right foot slope: 1.3477335534782844
# 2024-09-08 00:47:05,592 - INFO - Right foot slope: 1.3477335534782844
# 2024-09-08 00:47:05,734 - INFO - ===================== Processing frame 13 ==================================
# 2024-09-08 00:47:05,755 - INFO - Right foot slope: 1.189859850254554
# 2024-09-08 00:47:05,756 - INFO - Right foot slope: 1.189859850254554
# 2024-09-08 00:47:05,899 - INFO - ===================== Processing frame 14 ==================================
# 2024-09-08 00:47:05,921 - INFO - Right foot slope: 1.1719427769594
# 2024-09-08 00:47:05,922 - INFO - Right foot slope: 1.1719427769594
# 2024-09-08 00:47:06,065 - INFO - ===================== Processing frame 15 ==================================
# 2024-09-08 00:47:06,084 - INFO - Right foot slope: 1.2194277705717484
# 2024-09-08 00:47:06,085 - INFO - Right foot slope: 1.2194277705717484
# 2024-09-08 00:47:06,224 - INFO - ===================== Processing frame 16 ==================================
# 2024-09-08 00:47:06,243 - INFO - Right foot slope: 1.2785951501841153
# 2024-09-08 00:47:06,244 - INFO - Right foot slope: 1.2785951501841153
# 2024-09-08 00:47:06,383 - INFO - ===================== Processing frame 17 ==================================
# 2024-09-08 00:47:06,403 - INFO - Right foot slope: 1.4149840838246195
# 2024-09-08 00:47:06,403 - INFO - Right foot slope: 1.4149840838246195
# 2024-09-08 00:47:06,544 - INFO - ===================== Processing frame 18 ==================================
# 2024-09-08 00:47:06,565 - INFO - Right foot slope: 1.354541511414574
# 2024-09-08 00:47:06,565 - INFO - Right foot slope: 1.354541511414574
# 2024-09-08 00:47:06,703 - INFO - ===================== Processing frame 19 ==================================
# 2024-09-08 00:47:06,724 - INFO - Right foot slope: 1.321504974628127
# 2024-09-08 00:47:06,724 - INFO - Right foot slope: 1.321504974628127
# 2024-09-08 00:47:06,867 - INFO - ===================== Processing frame 20 ==================================
# 2024-09-08 00:47:06,886 - INFO - Right foot slope: 1.260401481158831
# 2024-09-08 00:47:06,887 - INFO - Right foot slope: 1.260401481158831
# 2024-09-08 00:47:07,031 - INFO - ===================== Processing frame 21 ==================================
# 2024-09-08 00:47:07,050 - INFO - Right foot slope: 1.2469569809447578
# 2024-09-08 00:47:07,051 - INFO - Right foot slope: 1.2469569809447578
# 2024-09-08 00:47:07,191 - INFO - ===================== Processing frame 22 ==================================
# 2024-09-08 00:47:07,210 - INFO - Right foot slope: 1.2358607408369504
# 2024-09-08 00:47:07,211 - INFO - Right foot slope: 1.2358607408369504
# 2024-09-08 00:47:07,351 - INFO - ===================== Processing frame 23 ==================================
# 2024-09-08 00:47:07,371 - INFO - Right foot slope: 1.2371415593416792
# 2024-09-08 00:47:07,371 - INFO - Right foot slope: 1.2371415593416792
# 2024-09-08 00:47:07,514 - INFO - ===================== Processing frame 24 ==================================
# 2024-09-08 00:47:07,533 - INFO - Right foot slope: 1.1860061836140863
# 2024-09-08 00:47:07,534 - INFO - Right foot slope: 1.1860061836140863
# 2024-09-08 00:47:07,674 - INFO - ===================== Processing frame 25 ==================================
# 2024-09-08 00:47:07,693 - INFO - Right foot slope: 1.145960808909902
# 2024-09-08 00:47:07,694 - INFO - Right foot slope: 1.145960808909902
# 2024-09-08 00:47:07,834 - INFO - ===================== Processing frame 26 ==================================
# 2024-09-08 00:47:07,854 - INFO - Right foot slope: 1.1011088020265078
# 2024-09-08 00:47:07,855 - INFO - Right foot slope: 1.1011088020265078
# 2024-09-08 00:47:07,999 - INFO - ===================== Processing frame 27 ==================================
# 2024-09-08 00:47:08,018 - INFO - Right foot slope: 1.0861904295494342
# 2024-09-08 00:47:08,019 - INFO - Right foot slope: 1.0861904295494342
# 2024-09-08 00:47:08,159 - INFO - ===================== Processing frame 28 ==================================
# 2024-09-08 00:47:08,178 - INFO - Right foot slope: 1.0979486422569078
# 2024-09-08 00:47:08,178 - INFO - Right foot slope: 1.0979486422569078
# 2024-09-08 00:47:08,319 - INFO - ===================== Processing frame 29 ==================================
# 2024-09-08 00:47:08,338 - INFO - Right foot slope: 1.0975719687037009
# 2024-09-08 00:47:08,339 - INFO - Right foot slope: 1.0975719687037009
# 2024-09-08 00:47:08,482 - INFO - ===================== Processing frame 30 ==================================
# 2024-09-08 00:47:08,501 - INFO - Right foot slope: 1.1059468493306426
# 2024-09-08 00:47:08,502 - INFO - Right foot slope: 1.1059468493306426
# 2024-09-08 00:47:08,642 - INFO - ===================== Processing frame 31 ==================================
# 2024-09-08 00:47:08,662 - INFO - Right foot slope: 1.0991037797704855
# 2024-09-08 00:47:08,662 - INFO - Right foot slope: 1.0991037797704855
# 2024-09-08 00:47:08,804 - INFO - ===================== Processing frame 32 ==================================
# 2024-09-08 00:47:08,824 - INFO - Right foot slope: 1.1021514401156338
# 2024-09-08 00:47:08,824 - INFO - Right foot slope: 1.1021514401156338
# 2024-09-08 00:47:08,969 - INFO - ===================== Processing frame 33 ==================================
# 2024-09-08 00:47:08,988 - INFO - Right foot slope: 1.1034023449370922
# 2024-09-08 00:47:08,989 - INFO - Right foot slope: 1.1034023449370922
# 2024-09-08 00:47:09,132 - INFO - ===================== Processing frame 34 ==================================
# 2024-09-08 00:47:09,152 - INFO - Right foot slope: 1.1402981767004883
# 2024-09-08 00:47:09,153 - INFO - Right foot slope: 1.1402981767004883
# 2024-09-08 00:47:09,295 - INFO - ===================== Processing frame 35 ==================================
# 2024-09-08 00:47:09,314 - INFO - Right foot slope: 1.2518632665573064
# 2024-09-08 00:47:09,314 - INFO - Right foot slope: 1.2518632665573064
# 2024-09-08 00:47:09,456 - INFO - ===================== Processing frame 36 ==================================
# 2024-09-08 00:47:09,475 - INFO - Right foot slope: 1.3737601523556215
# 2024-09-08 00:47:09,476 - INFO - Right foot slope: 1.3737601523556215
# 2024-09-08 00:47:09,634 - INFO - ===================== Processing frame 37 ==================================
# 2024-09-08 00:47:09,653 - INFO - Right foot slope: 1.5171838770210262
# 2024-09-08 00:47:09,654 - INFO - Right foot slope: 1.5171838770210262
# 2024-09-08 00:47:09,797 - INFO - ===================== Processing frame 38 ==================================
# 2024-09-08 00:47:09,817 - INFO - Right foot slope: 1.6959319169642963
# 2024-09-08 00:47:09,817 - INFO - Right foot slope: 1.6959319169642963
# 2024-09-08 00:47:09,961 - INFO - ===================== Processing frame 39 ==================================
# 2024-09-08 00:47:09,981 - INFO - Right foot slope: 1.9687078165610226
# 2024-09-08 00:47:09,981 - INFO - Right foot slope: 1.9687078165610226
# 2024-09-08 00:47:10,126 - INFO - ===================== Processing frame 40 ==================================
# 2024-09-08 00:47:10,145 - INFO - Right foot slope: 2.1477121929086898
# 2024-09-08 00:47:10,145 - INFO - Right foot slope: 2.1477121929086898
# 2024-09-08 00:47:10,286 - INFO - ===================== Processing frame 41 ==================================
# 2024-09-08 00:47:10,306 - INFO - Right foot slope: 2.339294882607092
# 2024-09-08 00:47:10,306 - INFO - Right foot slope: 2.339294882607092
# 2024-09-08 00:47:10,449 - INFO - ===================== Processing frame 42 ==================================
# 2024-09-08 00:47:10,468 - INFO - Right foot slope: 2.5603590928270803
# 2024-09-08 00:47:10,469 - INFO - Right foot slope: 2.5603590928270803
# 2024-09-08 00:47:10,615 - INFO - ===================== Processing frame 43 ==================================
# 2024-09-08 00:47:10,634 - INFO - Right foot slope: 2.9781803238856424
# 2024-09-08 00:47:10,635 - INFO - Right foot slope: 2.9781803238856424
# 2024-09-08 00:47:10,777 - INFO - ===================== Processing frame 44 ==================================
# 2024-09-08 00:47:10,797 - INFO - Right foot slope: 3.1739036086636077
# 2024-09-08 00:47:10,798 - INFO - Right foot slope: 3.1739036086636077
# 2024-09-08 00:47:10,938 - INFO - ===================== Processing frame 45 ==================================
# 2024-09-08 00:47:10,957 - INFO - Right foot slope: 3.5840632396471834
# 2024-09-08 00:47:10,958 - INFO - Right foot slope: 3.5840632396471834
# 2024-09-08 00:47:11,100 - INFO - ===================== Processing frame 46 ==================================
# 2024-09-08 00:47:11,120 - INFO - Right foot slope: 4.139802329098111
# 2024-09-08 00:47:11,121 - INFO - Right foot slope: 4.139802329098111
# 2024-09-08 00:47:11,267 - INFO - ===================== Processing frame 47 ==================================
# 2024-09-08 00:47:11,288 - INFO - Right foot slope: 4.722549504842079
# 2024-09-08 00:47:11,289 - INFO - Right foot slope: 4.722549504842079
# 2024-09-08 00:47:11,432 - INFO - ===================== Processing frame 48 ==================================
# 2024-09-08 00:47:11,451 - INFO - Right foot slope: 4.2935688093930775
# 2024-09-08 00:47:11,452 - INFO - Right foot slope: 4.2935688093930775
# 2024-09-08 00:47:11,594 - INFO - ===================== Processing frame 49 ==================================
# 2024-09-08 00:47:11,613 - INFO - Right foot slope: 4.003135854230993
# 2024-09-08 00:47:11,614 - INFO - Right foot slope: 4.003135854230993
# 2024-09-08 00:47:11,755 - INFO - ===================== Processing frame 50 ==================================
# 2024-09-08 00:47:11,774 - INFO - Right foot slope: 3.003233881184985
# 2024-09-08 00:47:11,775 - INFO - Right foot slope: 3.003233881184985
# 2024-09-08 00:47:11,919 - INFO - ===================== Processing frame 51 ==================================
# 2024-09-08 00:47:11,938 - INFO - Right foot slope: 2.750483798126187
# 2024-09-08 00:47:11,939 - INFO - Right foot slope: 2.750483798126187
# 2024-09-08 00:47:12,084 - INFO - ===================== Processing frame 52 ==================================
# 2024-09-08 00:47:12,104 - INFO - Right foot slope: 2.6543181278235366
# 2024-09-08 00:47:12,105 - INFO - Right foot slope: 2.6543181278235366
# 2024-09-08 00:47:12,249 - INFO - ===================== Processing frame 53 ==================================
# 2024-09-08 00:47:12,269 - INFO - Right foot slope: 2.3877747035931676
# 2024-09-08 00:47:12,269 - INFO - Right foot slope: 2.3877747035931676
# 2024-09-08 00:47:12,412 - INFO - ===================== Processing frame 54 ==================================
# 2024-09-08 00:47:12,431 - INFO - Right foot slope: 1.7950208022362182
# 2024-09-08 00:47:12,431 - INFO - Right foot slope: 1.7950208022362182
# 2024-09-08 00:47:12,572 - INFO - ===================== Processing frame 55 ==================================
# 2024-09-08 00:47:12,591 - INFO - Right foot slope: 1.6819071404010868
# 2024-09-08 00:47:12,592 - INFO - Right foot slope: 1.6819071404010868
# 2024-09-08 00:47:12,733 - INFO - ===================== Processing frame 56 ==================================
# 2024-09-08 00:47:12,753 - INFO - Right foot slope: 1.2170867365734874
# 2024-09-08 00:47:12,754 - INFO - Right foot slope: 1.2170867365734874
# 2024-09-08 00:47:12,896 - INFO - ===================== Processing frame 57 ==================================
# 2024-09-08 00:47:12,916 - INFO - Right foot slope: 1.1111045589786537
# 2024-09-08 00:47:12,916 - INFO - Right foot slope: 1.1111045589786537
# 2024-09-08 00:47:13,059 - INFO - ===================== Processing frame 58 ==================================
# 2024-09-08 00:47:13,078 - INFO - Right foot slope: 1.0488435362465314
# 2024-09-08 00:47:13,079 - INFO - Right foot slope: 1.0488435362465314
# 2024-09-08 00:47:13,221 - INFO - ===================== Processing frame 59 ==================================
# 2024-09-08 00:47:13,240 - INFO - Right foot slope: 0.9742032596047211
# 2024-09-08 00:47:13,241 - INFO - Right foot slope: 0.9742032596047211
# 2024-09-08 00:47:13,384 - INFO - ===================== Processing frame 60 ==================================
# 2024-09-08 00:47:13,403 - INFO - Right foot slope: 1.003040332897786
# 2024-09-08 00:47:13,404 - INFO - Right foot slope: 1.003040332897786
# 2024-09-08 00:47:13,548 - INFO - ===================== Processing frame 61 ==================================
# 2024-09-08 00:47:13,568 - INFO - Right foot slope: 0.9485024649884386
# 2024-09-08 00:47:13,568 - INFO - Right foot slope: 0.9485024649884386
# 2024-09-08 00:47:13,711 - INFO - ===================== Processing frame 62 ==================================
# 2024-09-08 00:47:13,731 - INFO - Right foot slope: 0.8223832492844914
# 2024-09-08 00:47:13,732 - INFO - Right foot slope: 0.8223832492844914
# 2024-09-08 00:47:13,733 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:13,872 - INFO - ===================== Processing frame 63 ==================================
# 2024-09-08 00:47:13,892 - INFO - Right foot slope: 0.7506353227487407
# 2024-09-08 00:47:13,892 - INFO - Right foot slope: 0.7506353227487407
# 2024-09-08 00:47:13,894 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,035 - INFO - ===================== Processing frame 64 ==================================
# 2024-09-08 00:47:14,054 - INFO - Right foot slope: 0.7360594530969833
# 2024-09-08 00:47:14,054 - INFO - Right foot slope: 0.7360594530969833
# 2024-09-08 00:47:14,056 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,198 - INFO - ===================== Processing frame 65 ==================================
# 2024-09-08 00:47:14,218 - INFO - Right foot slope: 0.6306336542263085
# 2024-09-08 00:47:14,219 - INFO - Right foot slope: 0.6306336542263085
# 2024-09-08 00:47:14,220 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,361 - INFO - ===================== Processing frame 66 ==================================
# 2024-09-08 00:47:14,380 - INFO - Right foot slope: 0.5870301830362625
# 2024-09-08 00:47:14,381 - INFO - Right foot slope: 0.5870301830362625
# 2024-09-08 00:47:14,382 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,529 - INFO - ===================== Processing frame 67 ==================================
# 2024-09-08 00:47:14,549 - INFO - Right foot slope: 0.5751226280313191
# 2024-09-08 00:47:14,549 - INFO - Right foot slope: 0.5751226280313191
# 2024-09-08 00:47:14,551 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,691 - INFO - ===================== Processing frame 68 ==================================
# 2024-09-08 00:47:14,710 - INFO - Right foot slope: 0.46028535149968786
# 2024-09-08 00:47:14,711 - INFO - Right foot slope: 0.46028535149968786
# 2024-09-08 00:47:14,713 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,853 - INFO - ===================== Processing frame 69 ==================================
# 2024-09-08 00:47:14,873 - INFO - Right foot slope: 0.38584564058454524
# 2024-09-08 00:47:14,874 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:14,874 - INFO - First ground contact detected
# 2024-09-08 00:47:14,874 - INFO - Right foot slope: 0.38584564058454524
# 2024-09-08 00:47:14,876 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,018 - INFO - ===================== Processing frame 70 ==================================
# 2024-09-08 00:47:15,038 - INFO - Right foot slope: 0.3771666542421876
# 2024-09-08 00:47:15,039 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,039 - INFO - Right foot slope: 0.3771666542421876
# 2024-09-08 00:47:15,041 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,183 - INFO - ===================== Processing frame 71 ==================================
# 2024-09-08 00:47:15,203 - INFO - Right foot slope: 0.38637376545506336
# 2024-09-08 00:47:15,204 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,204 - INFO - Right foot slope: 0.38637376545506336
# 2024-09-08 00:47:15,206 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,349 - INFO - ===================== Processing frame 72 ==================================
# 2024-09-08 00:47:15,368 - INFO - Right foot slope: 0.425827826154416
# 2024-09-08 00:47:15,369 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,369 - INFO - Right foot slope: 0.425827826154416
# 2024-09-08 00:47:15,371 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,512 - INFO - ===================== Processing frame 73 ==================================
# 2024-09-08 00:47:15,531 - INFO - Right foot slope: 0.4783593632012832
# 2024-09-08 00:47:15,532 - INFO - Foot is off the ground
# 2024-09-08 00:47:15,532 - INFO - Right foot slope: 0.4783593632012832
# 2024-09-08 00:47:15,533 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,672 - INFO - ===================== Processing frame 74 ==================================
# 2024-09-08 00:47:15,692 - INFO - Right foot slope: 0.5898210501225668
# 2024-09-08 00:47:15,693 - INFO - Right foot slope: 0.5898210501225668
# 2024-09-08 00:47:15,694 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:15,835 - INFO - ===================== Processing frame 75 ==================================
# 2024-09-08 00:47:15,855 - INFO - Right foot slope: 0.6276036831673232
# 2024-09-08 00:47:15,855 - INFO - Right foot slope: 0.6276036831673232
# 2024-09-08 00:47:15,857 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,000 - INFO - ===================== Processing frame 76 ==================================
# 2024-09-08 00:47:16,019 - INFO - Right foot slope: 0.6046833460796096
# 2024-09-08 00:47:16,020 - INFO - Right foot slope: 0.6046833460796096
# 2024-09-08 00:47:16,021 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,161 - INFO - ===================== Processing frame 77 ==================================
# 2024-09-08 00:47:16,182 - INFO - Right foot slope: 0.5843101797111995
# 2024-09-08 00:47:16,182 - INFO - Right foot slope: 0.5843101797111995
# 2024-09-08 00:47:16,184 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,323 - INFO - ===================== Processing frame 78 ==================================
# 2024-09-08 00:47:16,343 - INFO - Right foot slope: 0.5961522957076512
# 2024-09-08 00:47:16,343 - INFO - Right foot slope: 0.5961522957076512
# 2024-09-08 00:47:16,345 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,486 - INFO - ===================== Processing frame 79 ==================================
# 2024-09-08 00:47:16,505 - INFO - Right foot slope: 0.6257748076489232
# 2024-09-08 00:47:16,506 - INFO - Right foot slope: 0.6257748076489232
# 2024-09-08 00:47:16,507 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,650 - INFO - ===================== Processing frame 80 ==================================
# 2024-09-08 00:47:16,704 - INFO - Right foot slope: 0.6582386670561355
# 2024-09-08 00:47:16,704 - INFO - Right foot slope: 0.6582386670561355
# 2024-09-08 00:47:16,706 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:16,850 - INFO - ===================== Processing frame 81 ==================================
# 2024-09-08 00:47:16,869 - INFO - Right foot slope: 0.6603542782505666
# 2024-09-08 00:47:16,870 - INFO - Right foot slope: 0.6603542782505666
# 2024-09-08 00:47:16,871 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,011 - INFO - ===================== Processing frame 82 ==================================
# 2024-09-08 00:47:17,031 - INFO - Right foot slope: 0.6815592621223122
# 2024-09-08 00:47:17,031 - INFO - Right foot slope: 0.6815592621223122
# 2024-09-08 00:47:17,033 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,173 - INFO - ===================== Processing frame 83 ==================================
# 2024-09-08 00:47:17,192 - INFO - Right foot slope: 0.662241523566676
# 2024-09-08 00:47:17,193 - INFO - Right foot slope: 0.662241523566676
# 2024-09-08 00:47:17,194 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,334 - INFO - ===================== Processing frame 84 ==================================
# 2024-09-08 00:47:17,353 - INFO - Right foot slope: 0.649553319009386
# 2024-09-08 00:47:17,354 - INFO - Right foot slope: 0.649553319009386
# 2024-09-08 00:47:17,355 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,497 - INFO - ===================== Processing frame 85 ==================================
# 2024-09-08 00:47:17,516 - INFO - Right foot slope: 0.6003050023864044
# 2024-09-08 00:47:17,517 - INFO - Right foot slope: 0.6003050023864044
# 2024-09-08 00:47:17,518 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,655 - INFO - ===================== Processing frame 86 ==================================
# 2024-09-08 00:47:17,675 - INFO - Right foot slope: 0.5948044492407859
# 2024-09-08 00:47:17,675 - INFO - Right foot slope: 0.5948044492407859
# 2024-09-08 00:47:17,677 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,818 - INFO - ===================== Processing frame 87 ==================================
# 2024-09-08 00:47:17,838 - INFO - Right foot slope: 0.6063754375643229
# 2024-09-08 00:47:17,839 - INFO - Right foot slope: 0.6063754375643229
# 2024-09-08 00:47:17,840 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:17,982 - INFO - ===================== Processing frame 88 ==================================
# 2024-09-08 00:47:18,003 - INFO - Right foot slope: 0.6368900976390105
# 2024-09-08 00:47:18,004 - INFO - Right foot slope: 0.6368900976390105
# 2024-09-08 00:47:18,005 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,148 - INFO - ===================== Processing frame 89 ==================================
# 2024-09-08 00:47:18,167 - INFO - Right foot slope: 0.7066066713126703
# 2024-09-08 00:47:18,168 - INFO - Right foot slope: 0.7066066713126703
# 2024-09-08 00:47:18,169 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,310 - INFO - ===================== Processing frame 90 ==================================
# 2024-09-08 00:47:18,329 - INFO - Right foot slope: 0.7269039993145803
# 2024-09-08 00:47:18,330 - INFO - Right foot slope: 0.7269039993145803
# 2024-09-08 00:47:18,331 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,472 - INFO - ===================== Processing frame 91 ==================================
# 2024-09-08 00:47:18,493 - INFO - Right foot slope: 0.7319595966395669
# 2024-09-08 00:47:18,493 - INFO - Right foot slope: 0.7319595966395669
# 2024-09-08 00:47:18,495 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,633 - INFO - ===================== Processing frame 92 ==================================
# 2024-09-08 00:47:18,653 - INFO - Right foot slope: 0.7511554876278189
# 2024-09-08 00:47:18,653 - INFO - Right foot slope: 0.7511554876278189
# 2024-09-08 00:47:18,655 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,798 - INFO - ===================== Processing frame 93 ==================================
# 2024-09-08 00:47:18,817 - INFO - Right foot slope: 0.7671614413012615
# 2024-09-08 00:47:18,818 - INFO - Right foot slope: 0.7671614413012615
# 2024-09-08 00:47:18,819 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:18,958 - INFO - ===================== Processing frame 94 ==================================
# 2024-09-08 00:47:18,978 - INFO - Right foot slope: 0.7991790675534436
# 2024-09-08 00:47:18,979 - INFO - Right foot slope: 0.7991790675534436
# 2024-09-08 00:47:18,980 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:19,119 - INFO - ===================== Processing frame 95 ==================================
# 2024-09-08 00:47:19,138 - INFO - Right foot slope: 0.8252380993242927
# 2024-09-08 00:47:19,139 - INFO - Right foot slope: 0.8252380993242927
# 2024-09-08 00:47:19,140 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:19,282 - INFO - ===================== Processing frame 96 ==================================
# 2024-09-08 00:47:19,302 - INFO - Right foot slope: 0.8950207025102749
# 2024-09-08 00:47:19,302 - INFO - Right foot slope: 0.8950207025102749
# 2024-09-08 00:47:19,304 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:19,442 - INFO - ===================== Processing frame 97 ==================================
# 2024-09-08 00:47:19,461 - INFO - Right foot slope: 1.005123732911328
# 2024-09-08 00:47:19,461 - INFO - Right foot slope: 1.005123732911328
# 2024-09-08 00:47:19,601 - INFO - ===================== Processing frame 98 ==================================
# 2024-09-08 00:47:19,620 - INFO - Right foot slope: 1.171444311094497
# 2024-09-08 00:47:19,621 - INFO - Right foot slope: 1.171444311094497
# 2024-09-08 00:47:19,762 - INFO - ===================== Processing frame 99 ==================================
# 2024-09-08 00:47:19,782 - INFO - Right foot slope: 1.1417917467313454
# 2024-09-08 00:47:19,783 - INFO - Right foot slope: 1.1417917467313454
# 2024-09-08 00:47:19,934 - INFO - ===================== Processing frame 100 ==================================
# 2024-09-08 00:47:19,954 - INFO - Right foot slope: 1.0467343379689666
# 2024-09-08 00:47:19,954 - INFO - Right foot slope: 1.0467343379689666
# 2024-09-08 00:47:20,094 - INFO - ===================== Processing frame 101 ==================================
# 2024-09-08 00:47:20,116 - INFO - Right foot slope: 1.080943475576474
# 2024-09-08 00:47:20,116 - INFO - Right foot slope: 1.080943475576474
# 2024-09-08 00:47:20,270 - INFO - ===================== Processing frame 102 ==================================
# 2024-09-08 00:47:20,289 - INFO - Right foot slope: 1.0694908000577688
# 2024-09-08 00:47:20,290 - INFO - Right foot slope: 1.0694908000577688
# 2024-09-08 00:47:20,433 - INFO - ===================== Processing frame 103 ==================================
# 2024-09-08 00:47:20,452 - INFO - Right foot slope: 0.9898488551485233
# 2024-09-08 00:47:20,453 - INFO - Right foot slope: 0.9898488551485233
# 2024-09-08 00:47:20,594 - INFO - ===================== Processing frame 104 ==================================
# 2024-09-08 00:47:20,614 - INFO - Right foot slope: 1.0076897990010127
# 2024-09-08 00:47:20,615 - INFO - Right foot slope: 1.0076897990010127
# 2024-09-08 00:47:20,756 - INFO - ===================== Processing frame 105 ==================================
# 2024-09-08 00:47:20,775 - INFO - Right foot slope: 0.9350469224399669
# 2024-09-08 00:47:20,776 - INFO - Right foot slope: 0.9350469224399669
# 2024-09-08 00:47:20,916 - INFO - ===================== Processing frame 106 ==================================
# 2024-09-08 00:47:20,935 - INFO - Right foot slope: 0.8706836578589137
# 2024-09-08 00:47:20,936 - INFO - Right foot slope: 0.8706836578589137
# 2024-09-08 00:47:20,937 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,078 - INFO - ===================== Processing frame 107 ==================================
# 2024-09-08 00:47:21,097 - INFO - Right foot slope: 0.8164078512519289
# 2024-09-08 00:47:21,097 - INFO - Right foot slope: 0.8164078512519289
# 2024-09-08 00:47:21,099 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,237 - INFO - ===================== Processing frame 108 ==================================
# 2024-09-08 00:47:21,257 - INFO - Right foot slope: 0.8021792436250429
# 2024-09-08 00:47:21,257 - INFO - Right foot slope: 0.8021792436250429
# 2024-09-08 00:47:21,259 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,400 - INFO - ===================== Processing frame 109 ==================================
# 2024-09-08 00:47:21,419 - INFO - Right foot slope: 0.7900530042252674
# 2024-09-08 00:47:21,420 - INFO - Right foot slope: 0.7900530042252674
# 2024-09-08 00:47:21,421 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,562 - INFO - ===================== Processing frame 110 ==================================
# 2024-09-08 00:47:21,582 - INFO - Right foot slope: 0.7820760120817825
# 2024-09-08 00:47:21,582 - INFO - Right foot slope: 0.7820760120817825
# 2024-09-08 00:47:21,584 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,723 - INFO - ===================== Processing frame 111 ==================================
# 2024-09-08 00:47:21,743 - INFO - Right foot slope: 0.7774243005319126
# 2024-09-08 00:47:21,744 - INFO - Right foot slope: 0.7774243005319126
# 2024-09-08 00:47:21,745 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:21,885 - INFO - ===================== Processing frame 112 ==================================
# 2024-09-08 00:47:21,905 - INFO - Right foot slope: 0.7770410016366553
# 2024-09-08 00:47:21,905 - INFO - Right foot slope: 0.7770410016366553
# 2024-09-08 00:47:21,907 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:22,050 - INFO - ===================== Processing frame 113 ==================================
# 2024-09-08 00:47:22,069 - INFO - Right foot slope: 0.7964539707228344
# 2024-09-08 00:47:22,070 - INFO - Right foot slope: 0.7964539707228344
# 2024-09-08 00:47:22,071 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:22,212 - INFO - ===================== Processing frame 114 ==================================
# 2024-09-08 00:47:22,231 - INFO - Right foot slope: 0.8261264352481279
# 2024-09-08 00:47:22,232 - INFO - Right foot slope: 0.8261264352481279
# 2024-09-08 00:47:22,233 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:22,375 - INFO - ===================== Processing frame 115 ==================================
# 2024-09-08 00:47:22,395 - INFO - Right foot slope: 0.8849804513641188
# 2024-09-08 00:47:22,396 - INFO - Right foot slope: 0.8849804513641188
# 2024-09-08 00:47:22,397 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:22,545 - INFO - ===================== Processing frame 116 ==================================
# 2024-09-08 00:47:22,565 - INFO - Right foot slope: 0.9392579958261491
# 2024-09-08 00:47:22,565 - INFO - Right foot slope: 0.9392579958261491
# 2024-09-08 00:47:22,708 - INFO - ===================== Processing frame 117 ==================================
# 2024-09-08 00:47:22,727 - INFO - Right foot slope: 1.0836441873286127
# 2024-09-08 00:47:22,728 - INFO - Right foot slope: 1.0836441873286127
# 2024-09-08 00:47:22,868 - INFO - ===================== Processing frame 118 ==================================
# 2024-09-08 00:47:22,888 - INFO - Right foot slope: 1.1458138889589586
# 2024-09-08 00:47:22,888 - INFO - Right foot slope: 1.1458138889589586
# 2024-09-08 00:47:23,032 - INFO - ===================== Processing frame 119 ==================================
# 2024-09-08 00:47:23,051 - INFO - Right foot slope: 1.18051305029488
# 2024-09-08 00:47:23,052 - INFO - Right foot slope: 1.18051305029488
# 2024-09-08 00:47:23,194 - INFO - ===================== Processing frame 120 ==================================
# 2024-09-08 00:47:23,213 - INFO - Right foot slope: 1.3157838965632531
# 2024-09-08 00:47:23,213 - INFO - Right foot slope: 1.3157838965632531
# 2024-09-08 00:47:23,356 - INFO - ===================== Processing frame 121 ==================================
# 2024-09-08 00:47:23,377 - INFO - Right foot slope: 1.5521971320821124
# 2024-09-08 00:47:23,377 - INFO - Right foot slope: 1.5521971320821124
# 2024-09-08 00:47:23,516 - INFO - ===================== Processing frame 122 ==================================
# 2024-09-08 00:47:23,536 - INFO - Right foot slope: 1.8691300196352418
# 2024-09-08 00:47:23,536 - INFO - Right foot slope: 1.8691300196352418
# 2024-09-08 00:47:23,677 - INFO - ===================== Processing frame 123 ==================================
# 2024-09-08 00:47:23,696 - INFO - Right foot slope: 2.1329430767446276
# 2024-09-08 00:47:23,697 - INFO - Right foot slope: 2.1329430767446276
# 2024-09-08 00:47:23,838 - INFO - ===================== Processing frame 124 ==================================
# 2024-09-08 00:47:23,858 - INFO - Right foot slope: 2.651045510052415
# 2024-09-08 00:47:23,858 - INFO - Right foot slope: 2.651045510052415
# 2024-09-08 00:47:24,000 - INFO - ===================== Processing frame 125 ==================================
# 2024-09-08 00:47:24,019 - INFO - Right foot slope: 3.2536098791978376
# 2024-09-08 00:47:24,020 - INFO - Right foot slope: 3.2536098791978376
# 2024-09-08 00:47:24,155 - INFO - ===================== Processing frame 126 ==================================
# 2024-09-08 00:47:24,175 - INFO - Right foot slope: 3.8777295077410803
# 2024-09-08 00:47:24,175 - INFO - Right foot slope: 3.8777295077410803
# 2024-09-08 00:47:24,319 - INFO - ===================== Processing frame 127 ==================================
# 2024-09-08 00:47:24,338 - INFO - Right foot slope: 4.6726757235914445
# 2024-09-08 00:47:24,339 - INFO - Right foot slope: 4.6726757235914445
# 2024-09-08 00:47:24,481 - INFO - ===================== Processing frame 128 ==================================
# 2024-09-08 00:47:24,500 - INFO - Right foot slope: 4.85946048759748
# 2024-09-08 00:47:24,501 - INFO - Right foot slope: 4.85946048759748
# 2024-09-08 00:47:24,642 - INFO - ===================== Processing frame 129 ==================================
# 2024-09-08 00:47:24,661 - INFO - Right foot slope: 4.929181314883897
# 2024-09-08 00:47:24,662 - INFO - Right foot slope: 4.929181314883897
# 2024-09-08 00:47:24,801 - INFO - ===================== Processing frame 130 ==================================
# 2024-09-08 00:47:24,821 - INFO - Right foot slope: 5.117703478668701
# 2024-09-08 00:47:24,822 - INFO - Right foot slope: 5.117703478668701
# 2024-09-08 00:47:24,964 - INFO - ===================== Processing frame 131 ==================================
# 2024-09-08 00:47:24,984 - INFO - Right foot slope: 4.766270403270134
# 2024-09-08 00:47:24,984 - INFO - Right foot slope: 4.766270403270134
# 2024-09-08 00:47:25,124 - INFO - ===================== Processing frame 132 ==================================
# 2024-09-08 00:47:25,144 - INFO - Right foot slope: 4.227147386149731
# 2024-09-08 00:47:25,145 - INFO - Right foot slope: 4.227147386149731
# 2024-09-08 00:47:25,299 - INFO - ===================== Processing frame 133 ==================================
# 2024-09-08 00:47:25,319 - INFO - Right foot slope: 3.0863086679378027
# 2024-09-08 00:47:25,319 - INFO - Right foot slope: 3.0863086679378027
# 2024-09-08 00:47:25,463 - INFO - ===================== Processing frame 134 ==================================
# 2024-09-08 00:47:25,485 - INFO - Right foot slope: 3.348972198376715
# 2024-09-08 00:47:25,486 - INFO - Right foot slope: 3.348972198376715
# 2024-09-08 00:47:25,632 - INFO - ===================== Processing frame 135 ==================================
# 2024-09-08 00:47:25,651 - INFO - Right foot slope: 1.8726175602182287
# 2024-09-08 00:47:25,651 - INFO - Right foot slope: 1.8726175602182287
# 2024-09-08 00:47:25,790 - INFO - ===================== Processing frame 136 ==================================
# 2024-09-08 00:47:25,810 - INFO - Right foot slope: 1.4919088437375922
# 2024-09-08 00:47:25,810 - INFO - Right foot slope: 1.4919088437375922
# 2024-09-08 00:47:25,951 - INFO - ===================== Processing frame 137 ==================================
# 2024-09-08 00:47:25,970 - INFO - Right foot slope: 1.370305578573694
# 2024-09-08 00:47:25,971 - INFO - Right foot slope: 1.370305578573694
# 2024-09-08 00:47:26,112 - INFO - ===================== Processing frame 138 ==================================
# 2024-09-08 00:47:26,131 - INFO - Right foot slope: 1.2156020152225355
# 2024-09-08 00:47:26,131 - INFO - Right foot slope: 1.2156020152225355
# 2024-09-08 00:47:26,273 - INFO - ===================== Processing frame 139 ==================================
# 2024-09-08 00:47:26,292 - INFO - Right foot slope: 1.2663570826485406
# 2024-09-08 00:47:26,293 - INFO - Right foot slope: 1.2663570826485406
# 2024-09-08 00:47:26,434 - INFO - ===================== Processing frame 140 ==================================
# 2024-09-08 00:47:26,454 - INFO - Right foot slope: 1.2358209127250164
# 2024-09-08 00:47:26,454 - INFO - Right foot slope: 1.2358209127250164
# 2024-09-08 00:47:26,597 - INFO - ===================== Processing frame 141 ==================================
# 2024-09-08 00:47:26,617 - INFO - Right foot slope: 1.0954507151272967
# 2024-09-08 00:47:26,617 - INFO - Right foot slope: 1.0954507151272967
# 2024-09-08 00:47:26,760 - INFO - ===================== Processing frame 142 ==================================
# 2024-09-08 00:47:26,784 - INFO - Right foot slope: 0.9419075302920091
# 2024-09-08 00:47:26,784 - INFO - Right foot slope: 0.9419075302920091
# 2024-09-08 00:47:26,924 - INFO - ===================== Processing frame 143 ==================================
# 2024-09-08 00:47:26,943 - INFO - Right foot slope: 0.633362771534911
# 2024-09-08 00:47:26,944 - INFO - Right foot slope: 0.633362771534911
# 2024-09-08 00:47:26,945 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,085 - INFO - ===================== Processing frame 144 ==================================
# 2024-09-08 00:47:27,105 - INFO - Right foot slope: 0.5129416899638408
# 2024-09-08 00:47:27,106 - INFO - Right foot slope: 0.5129416899638408
# 2024-09-08 00:47:27,108 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,251 - INFO - ===================== Processing frame 145 ==================================
# 2024-09-08 00:47:27,270 - INFO - Right foot slope: 0.4705787055787634
# 2024-09-08 00:47:27,271 - INFO - Right foot slope: 0.4705787055787634
# 2024-09-08 00:47:27,272 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,412 - INFO - ===================== Processing frame 146 ==================================
# 2024-09-08 00:47:27,432 - INFO - Right foot slope: 0.44247714233288316
# 2024-09-08 00:47:27,432 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,433 - INFO - Stride length recorded: 93.76797217101132 cm
# 2024-09-08 00:47:27,433 - INFO - Right foot slope: 0.44247714233288316
# 2024-09-08 00:47:27,435 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,572 - INFO - ===================== Processing frame 147 ==================================
# 2024-09-08 00:47:27,592 - INFO - Right foot slope: 0.39751967724311027
# 2024-09-08 00:47:27,592 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,593 - INFO - First ground contact detected
# 2024-09-08 00:47:27,593 - INFO - Right foot slope: 0.39751967724311027
# 2024-09-08 00:47:27,595 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,735 - INFO - ===================== Processing frame 148 ==================================
# 2024-09-08 00:47:27,755 - INFO - Right foot slope: 0.34492886238857073
# 2024-09-08 00:47:27,755 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,756 - INFO - Right foot slope: 0.34492886238857073
# 2024-09-08 00:47:27,757 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,900 - INFO - ===================== Processing frame 149 ==================================
# 2024-09-08 00:47:27,919 - INFO - Right foot slope: 0.34313581597662346
# 2024-09-08 00:47:27,920 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:27,920 - INFO - Right foot slope: 0.34313581597662346
# 2024-09-08 00:47:27,922 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,072 - INFO - ===================== Processing frame 150 ==================================
# 2024-09-08 00:47:28,092 - INFO - Right foot slope: 0.3541532762963069
# 2024-09-08 00:47:28,093 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,093 - INFO - Right foot slope: 0.3541532762963069
# 2024-09-08 00:47:28,095 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,235 - INFO - ===================== Processing frame 151 ==================================
# 2024-09-08 00:47:28,254 - INFO - Right foot slope: 0.3912391168049324
# 2024-09-08 00:47:28,255 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,255 - INFO - Right foot slope: 0.3912391168049324
# 2024-09-08 00:47:28,257 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,400 - INFO - ===================== Processing frame 152 ==================================
# 2024-09-08 00:47:28,420 - INFO - Right foot slope: 0.42357474792591254
# 2024-09-08 00:47:28,420 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,421 - INFO - Right foot slope: 0.42357474792591254
# 2024-09-08 00:47:28,422 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,565 - INFO - ===================== Processing frame 153 ==================================
# 2024-09-08 00:47:28,584 - INFO - Right foot slope: 0.4106563785944134
# 2024-09-08 00:47:28,585 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,585 - INFO - Right foot slope: 0.4106563785944134
# 2024-09-08 00:47:28,586 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,728 - INFO - ===================== Processing frame 154 ==================================
# 2024-09-08 00:47:28,748 - INFO - Right foot slope: 0.4277540581956347
# 2024-09-08 00:47:28,748 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,749 - INFO - Right foot slope: 0.4277540581956347
# 2024-09-08 00:47:28,750 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:28,892 - INFO - ===================== Processing frame 155 ==================================
# 2024-09-08 00:47:28,912 - INFO - Right foot slope: 0.48374858300759016
# 2024-09-08 00:47:28,912 - INFO - Foot is off the ground
# 2024-09-08 00:47:28,913 - INFO - Right foot slope: 0.48374858300759016
# 2024-09-08 00:47:28,915 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,067 - INFO - ===================== Processing frame 156 ==================================
# 2024-09-08 00:47:29,089 - INFO - Right foot slope: 0.5082571487354745
# 2024-09-08 00:47:29,089 - INFO - Right foot slope: 0.5082571487354745
# 2024-09-08 00:47:29,091 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,248 - INFO - ===================== Processing frame 157 ==================================
# 2024-09-08 00:47:29,268 - INFO - Right foot slope: 0.5769085374968791
# 2024-09-08 00:47:29,268 - INFO - Right foot slope: 0.5769085374968791
# 2024-09-08 00:47:29,270 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,415 - INFO - ===================== Processing frame 158 ==================================
# 2024-09-08 00:47:29,435 - INFO - Right foot slope: 0.5947432251755669
# 2024-09-08 00:47:29,436 - INFO - Right foot slope: 0.5947432251755669
# 2024-09-08 00:47:29,437 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,582 - INFO - ===================== Processing frame 159 ==================================
# 2024-09-08 00:47:29,601 - INFO - Right foot slope: 0.60351605327469
# 2024-09-08 00:47:29,602 - INFO - Right foot slope: 0.60351605327469
# 2024-09-08 00:47:29,603 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,750 - INFO - ===================== Processing frame 160 ==================================
# 2024-09-08 00:47:29,770 - INFO - Right foot slope: 0.6311826002085985
# 2024-09-08 00:47:29,771 - INFO - Right foot slope: 0.6311826002085985
# 2024-09-08 00:47:29,773 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:29,938 - INFO - ===================== Processing frame 161 ==================================
# 2024-09-08 00:47:29,959 - INFO - Right foot slope: 0.6158383723786697
# 2024-09-08 00:47:29,959 - INFO - Right foot slope: 0.6158383723786697
# 2024-09-08 00:47:29,961 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:30,102 - INFO - ===================== Processing frame 162 ==================================
# 2024-09-08 00:47:30,122 - INFO - Right foot slope: 0.5777916740148155
# 2024-09-08 00:47:30,123 - INFO - Right foot slope: 0.5777916740148155
# 2024-09-08 00:47:30,124 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:30,272 - INFO - ===================== Processing frame 163 ==================================
# 2024-09-08 00:47:30,292 - INFO - Right foot slope: 0.5714619356365177
# 2024-09-08 00:47:30,293 - INFO - Right foot slope: 0.5714619356365177
# 2024-09-08 00:47:30,294 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:30,434 - INFO - ===================== Processing frame 164 ==================================
# 2024-09-08 00:47:30,457 - INFO - Right foot slope: 0.5596120459401709
# 2024-09-08 00:47:30,457 - INFO - Right foot slope: 0.5596120459401709
# 2024-09-08 00:47:30,459 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:30,600 - INFO - ===================== Processing frame 165 ==================================
# 2024-09-08 00:47:30,619 - INFO - Right foot slope: 0.5407545624867779
# 2024-09-08 00:47:30,620 - INFO - Right foot slope: 0.5407545624867779
# 2024-09-08 00:47:30,621 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:47:30,765 - INFO - ===================== Processing frame 166 ==================================
# 2024-09-08 00:47:30,785 - INFO - Right foot slope: 0.5456100463867187
# ...
# 2024-09-08 00:48:02,989 - INFO - Right foot slope: 0.5174703260958415
# 2024-09-08 00:48:02,990 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,134 - INFO - ===================== Processing frame 362 ==================================
# 2024-09-08 00:48:03,153 - INFO - Right foot slope: 0.3765133496601712
# 2024-09-08 00:48:03,154 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,155 - INFO - Stride length recorded: 108.27566024503678 cm
# 2024-09-08 00:48:03,155 - INFO - Right foot slope: 0.3765133496601712
# 2024-09-08 00:48:03,157 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,302 - INFO - ===================== Processing frame 363 ==================================
# 2024-09-08 00:48:03,324 - INFO - Right foot slope: 0.2457300251083823
# 2024-09-08 00:48:03,349 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,359 - INFO - First ground contact detected
# 2024-09-08 00:48:03,360 - INFO - Right foot slope: 0.2457300251083823
# 2024-09-08 00:48:03,362 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,511 - INFO - ===================== Processing frame 364 ==================================
# 2024-09-08 00:48:03,531 - INFO - Right foot slope: 0.18965101109933183
# 2024-09-08 00:48:03,531 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,532 - INFO - Right foot slope: 0.18965101109933183
# 2024-09-08 00:48:03,533 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,677 - INFO - ===================== Processing frame 365 ==================================
# 2024-09-08 00:48:03,696 - INFO - Right foot slope: 0.2403415288880009
# 2024-09-08 00:48:03,697 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,698 - INFO - Right foot slope: 0.2403415288880009
# 2024-09-08 00:48:03,699 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,840 - INFO - ===================== Processing frame 366 ==================================
# 2024-09-08 00:48:03,860 - INFO - Right foot slope: 0.33648840363234106
# 2024-09-08 00:48:03,860 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:03,861 - INFO - Right foot slope: 0.33648840363234106
# 2024-09-08 00:48:03,862 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,004 - INFO - ===================== Processing frame 367 ==================================
# 2024-09-08 00:48:04,023 - INFO - Right foot slope: 0.43691082690792393
# 2024-09-08 00:48:04,024 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,024 - INFO - Right foot slope: 0.43691082690792393
# 2024-09-08 00:48:04,026 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,164 - INFO - ===================== Processing frame 368 ==================================
# 2024-09-08 00:48:04,184 - INFO - Right foot slope: 0.5301129782462916
# 2024-09-08 00:48:04,185 - INFO - Foot is off the ground
# 2024-09-08 00:48:04,185 - INFO - Right foot slope: 0.5301129782462916
# 2024-09-08 00:48:04,187 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,340 - INFO - ===================== Processing frame 369 ==================================
# 2024-09-08 00:48:04,363 - INFO - Right foot slope: 0.5766511641046829
# 2024-09-08 00:48:04,363 - INFO - Right foot slope: 0.5766511641046829
# 2024-09-08 00:48:04,365 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,510 - INFO - ===================== Processing frame 370 ==================================
# 2024-09-08 00:48:04,530 - INFO - Right foot slope: 0.5938041317022209
# 2024-09-08 00:48:04,530 - INFO - Right foot slope: 0.5938041317022209
# 2024-09-08 00:48:04,532 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,671 - INFO - ===================== Processing frame 371 ==================================
# 2024-09-08 00:48:04,691 - INFO - Right foot slope: 0.6257731306857898
# 2024-09-08 00:48:04,692 - INFO - Right foot slope: 0.6257731306857898
# 2024-09-08 00:48:04,693 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:04,846 - INFO - ===================== Processing frame 372 ==================================
# 2024-09-08 00:48:04,865 - INFO - Right foot slope: 0.6503740533496983
# 2024-09-08 00:48:04,866 - INFO - Right foot slope: 0.6503740533496983
# 2024-09-08 00:48:04,868 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,009 - INFO - ===================== Processing frame 373 ==================================
# 2024-09-08 00:48:05,029 - INFO - Right foot slope: 0.6617605682754786
# 2024-09-08 00:48:05,030 - INFO - Right foot slope: 0.6617605682754786
# 2024-09-08 00:48:05,031 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,174 - INFO - ===================== Processing frame 374 ==================================
# 2024-09-08 00:48:05,193 - INFO - Right foot slope: 0.6952447876246438
# 2024-09-08 00:48:05,194 - INFO - Right foot slope: 0.6952447876246438
# 2024-09-08 00:48:05,195 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,335 - INFO - ===================== Processing frame 375 ==================================
# 2024-09-08 00:48:05,354 - INFO - Right foot slope: 0.7313619830257309
# 2024-09-08 00:48:05,355 - INFO - Right foot slope: 0.7313619830257309
# 2024-09-08 00:48:05,356 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,500 - INFO - ===================== Processing frame 376 ==================================
# 2024-09-08 00:48:05,519 - INFO - Right foot slope: 0.7406291190802173
# 2024-09-08 00:48:05,520 - INFO - Right foot slope: 0.7406291190802173
# 2024-09-08 00:48:05,522 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,659 - INFO - ===================== Processing frame 377 ==================================
# 2024-09-08 00:48:05,678 - INFO - Right foot slope: 0.6634085373670042
# 2024-09-08 00:48:05,679 - INFO - Right foot slope: 0.6634085373670042
# 2024-09-08 00:48:05,680 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,820 - INFO - ===================== Processing frame 378 ==================================
# 2024-09-08 00:48:05,840 - INFO - Right foot slope: 0.6722383375681104
# 2024-09-08 00:48:05,840 - INFO - Right foot slope: 0.6722383375681104
# 2024-09-08 00:48:05,842 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:05,993 - INFO - ===================== Processing frame 379 ==================================
# 2024-09-08 00:48:06,013 - INFO - Right foot slope: 0.6291349273653759
# 2024-09-08 00:48:06,014 - INFO - Right foot slope: 0.6291349273653759
# 2024-09-08 00:48:06,015 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,154 - INFO - ===================== Processing frame 380 ==================================
# 2024-09-08 00:48:06,174 - INFO - Right foot slope: 0.6129529338303936
# 2024-09-08 00:48:06,175 - INFO - Right foot slope: 0.6129529338303936
# 2024-09-08 00:48:06,176 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,317 - INFO - ===================== Processing frame 381 ==================================
# 2024-09-08 00:48:06,337 - INFO - Right foot slope: 0.698325573079945
# 2024-09-08 00:48:06,337 - INFO - Right foot slope: 0.698325573079945
# 2024-09-08 00:48:06,339 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,483 - INFO - ===================== Processing frame 382 ==================================
# 2024-09-08 00:48:06,503 - INFO - Right foot slope: 0.6286057053028468
# 2024-09-08 00:48:06,504 - INFO - Right foot slope: 0.6286057053028468
# 2024-09-08 00:48:06,506 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,648 - INFO - ===================== Processing frame 383 ==================================
# 2024-09-08 00:48:06,667 - INFO - Right foot slope: 0.6460743460331233
# 2024-09-08 00:48:06,668 - INFO - Right foot slope: 0.6460743460331233
# 2024-09-08 00:48:06,669 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,810 - INFO - ===================== Processing frame 384 ==================================
# 2024-09-08 00:48:06,830 - INFO - Right foot slope: 0.6671532964723381
# 2024-09-08 00:48:06,831 - INFO - Right foot slope: 0.6671532964723381
# 2024-09-08 00:48:06,833 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:06,986 - INFO - ===================== Processing frame 385 ==================================
# 2024-09-08 00:48:07,005 - INFO - Right foot slope: 0.7076099721388991
# 2024-09-08 00:48:07,006 - INFO - Right foot slope: 0.7076099721388991
# 2024-09-08 00:48:07,007 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:07,150 - INFO - ===================== Processing frame 386 ==================================
# 2024-09-08 00:48:07,170 - INFO - Right foot slope: 0.7388758276651111
# 2024-09-08 00:48:07,170 - INFO - Right foot slope: 0.7388758276651111
# 2024-09-08 00:48:07,172 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:07,314 - INFO - ===================== Processing frame 387 ==================================
# 2024-09-08 00:48:07,333 - INFO - Right foot slope: 0.8206140887405414
# 2024-09-08 00:48:07,334 - INFO - Right foot slope: 0.8206140887405414
# 2024-09-08 00:48:07,335 - INFO - Right foot is parallel to the ground
# 2024-09-08 00:48:07,475 - INFO - ===================== Processing frame 388 ==================================
# 2024-09-08 00:48:07,494 - INFO - Right foot slope: 0.9726271174928341
# 2024-09-08 00:48:07,495 - INFO - Right foot slope: 0.9726271174928341
# 2024-09-08 00:48:07,637 - INFO - ===================== Processing frame 389 ==================================
# 2024-09-08 00:48:07,657 - INFO - Right foot slope: 1.005653795027679
# 2024-09-08 00:48:07,657 - INFO - Right foot slope: 1.005653795027679
# 2024-09-08 00:48:07,802 - INFO - ===================== Processing frame 390 ==================================
# 2024-09-08 00:48:07,821 - INFO - Right foot slope: 1.0028719551057843
# 2024-09-08 00:48:07,822 - INFO - Right foot slope: 1.0028719551057843
# 2024-09-08 00:48:07,964 - INFO - ===================== Processing frame 391 ==================================
# 2024-09-08 00:48:07,984 - INFO - Right foot slope: 1.0953441291647323
# 2024-09-08 00:48:07,984 - INFO - Right foot slope: 1.0953441291647323
# 2024-09-08 00:48:08,138 - INFO - ===================== Processing frame 392 ==================================
# 2024-09-08 00:48:08,157 - INFO - Right foot slope: 1.047912764101677
# 2024-09-08 00:48:08,158 - INFO - Right foot slope: 1.047912764101677
# 2024-09-08 00:48:08,301 - INFO - ===================== Processing frame 393 ==================================
# 2024-09-08 00:48:08,321 - INFO - Right foot slope: 1.0708539259039054
# 2024-09-08 00:48:08,321 - INFO - Right foot slope: 1.0708539259039054
# 2024-09-08 00:48:08,465 - INFO - ===================== Processing frame 394 ==================================
# 2024-09-08 00:48:08,484 - INFO - Right foot slope: 1.1819117908985661
# 2024-09-08 00:48:08,485 - INFO - Right foot slope: 1.1819117908985661
# 2024-09-08 00:48:08,626 - INFO - ===================== Processing frame 395 ==================================
# 2024-09-08 00:48:08,645 - INFO - Right foot slope: 1.4326510295546926
# 2024-09-08 00:48:08,645 - INFO - Right foot slope: 1.4326510295546926
# 2024-09-08 00:48:08,788 - INFO - ===================== Processing frame 396 ==================================
# 2024-09-08 00:48:08,807 - INFO - Right foot slope: 1.412832485584406
# 2024-09-08 00:48:08,808 - INFO - Right foot slope: 1.412832485584406
# 2024-09-08 00:48:08,953 - INFO - ===================== Processing frame 397 ==================================
# 2024-09-08 00:48:08,972 - INFO - Right foot slope: 1.3231616992453876
# 2024-09-08 00:48:08,973 - INFO - Right foot slope: 1.3231616992453876
# 2024-09-08 00:48:09,116 - INFO - ===================== Processing frame 398 ==================================
# 2024-09-08 00:48:09,136 - INFO - Right foot slope: 1.2869099744643526
# 2024-09-08 00:48:09,136 - INFO - Right foot slope: 1.2869099744643526
# 2024-09-08 00:48:09,278 - INFO - ===================== Processing frame 399 ==================================
# 2024-09-08 00:48:09,298 - INFO - Right foot slope: 1.2327299136844012
# 2024-09-08 00:48:09,299 - INFO - Right foot slope: 1.2327299136844012
# 2024-09-08 00:48:09,442 - INFO - ===================== Processing frame 400 ==================================
# 2024-09-08 00:48:09,461 - INFO - Right foot slope: 1.2589080636246393
# 2024-09-08 00:48:09,462 - INFO - Right foot slope: 1.2589080636246393
# 2024-09-08 00:48:09,601 - INFO - ===================== Processing frame 401 ==================================
# 2024-09-08 00:48:09,621 - INFO - Right foot slope: 1.3694100439174188
# 2024-09-08 00:48:09,653 - INFO - Right foot slope: 1.3694100439174188
# 2024-09-08 00:48:09,803 - INFO - ===================== Processing frame 402 ==================================
# 2024-09-08 00:48:09,822 - INFO - Right foot slope: 1.4674304069791562
# 2024-09-08 00:48:09,823 - INFO - Right foot slope: 1.4674304069791562
# 2024-09-08 00:48:09,966 - INFO - ===================== Processing frame 403 ==================================
# 2024-09-08 00:48:10,100 - INFO - ===================== Processing frame 404 ==================================
# 2024-09-08 00:48:10,234 - INFO - ===================== Processing frame 405 ==================================
# 2024-09-08 00:48:10,365 - INFO - ===================== Processing frame 406 ==================================
# 2024-09-08 00:48:10,497 - INFO - ===================== Processing frame 407 ==================================
# 2024-09-08 00:48:10,630 - INFO - ===================== Processing frame 408 ==================================
# 2024-09-08 00:48:10,768 - INFO - ===================== Processing frame 409 ==================================
# 2024-09-08 00:48:10,919 - INFO - ===================== Processing frame 410 ==================================
# 2024-09-08 00:48:11,074 - INFO - ===================== Processing frame 411 ==================================
# 2024-09-08 00:48:11,229 - INFO - ===================== Processing frame 412 ==================================
# 2024-09-08 00:48:11,383 - INFO - ===================== Processing frame 413 ==================================
# 2024-09-08 00:48:11,538 - INFO - ===================== Processing frame 414 ==================================
# 2024-09-08 00:48:11,673 - INFO - ===================== Processing frame 415 ==================================
# 2024-09-08 00:48:11,830 - INFO - ===================== Processing frame 416 ==================================
# 2024-09-08 00:48:11,859 - INFO - Right foot slope: 39.75583566760037
# 2024-09-08 00:48:11,859 - INFO - Right foot slope: 39.75583566760037
# 2024-09-08 00:48:12,002 - INFO - ===================== Processing frame 417 ==================================
# 2024-09-08 00:48:12,134 - INFO - ===================== Processing frame 418 ==================================
# 2024-09-08 00:48:12,268 - INFO - ===================== Processing frame 419 ==================================
# 2024-09-08 00:48:12,410 - INFO - ===================== Processing frame 420 ==================================
# 2024-09-08 00:48:12,581 - INFO - ===================== Processing frame 421 ==================================
# 2024-09-08 00:48:12,716 - INFO - ===================== Processing frame 422 ==================================
# 2024-09-08 00:48:12,855 - INFO - ===================== Processing frame 423 ==================================
# 2024-09-08 00:48:12,992 - INFO - ===================== Processing frame 424 ==================================
# 2024-09-08 00:48:13,130 - INFO - ===================== Processing frame 425 ==================================
# 2024-09-08 00:48:13,282 - INFO - ===================== Processing frame 426 ==================================
# 2024-09-08 00:48:13,424 - INFO - ===================== Processing frame 427 ==================================
# 2024-09-08 00:48:13,514 - WARNING - End of video or cannot read the video file
# Average Stride Length: 126.1744569234932
# Time to walk 0 cm: 0 seconds
# Average Speed: 0 cm/second

# %%
print(strides)
print(np.sum(strides))
print(np.mean(strides))
# Out:
# [93.76797217101132, 97.59619489779173, 2.0364751939196752, 13.759839800973515, 108.27566024503678]
# 315.436142308733
# 63.0872284617466
